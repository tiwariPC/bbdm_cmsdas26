# %%
import importlib
import config.plot_pkl_variables as pp
pp = importlib.reload(pp)
pp.plot_all_variables_grid("output/output_2017_full.pkl")
# Out:
# Cutflow by region
# ------------------------------------------
# [sr]
#   all_events         : 1605702702
#   masspoint          : 1579855782
#   trigger            : 1579855782
#   njet_ge1           : 1327055176
#   nbjet_ge2          :  137832964
#   lepton_veto        :   84717866
#   min_dphi           :   33895809
#   met_pf_calo        :   19642084
#   recoil_gt_250      :     267199
#   signal_region      :     267199
#
# [zecr]
#   trigger            : 1579855782
#   zecr               :       8563
#
# [zmucr]
#   trigger            : 1579855782
#   zmucr              :       9794
#
# [tecr]
#   trigger            : 1579855782
#   tecr               :      74628
#
# [tmucr]
#   trigger            : 1579855782
#   tmucr              :      72085
# (<Figure size 993.6x4924.8 with 57 Axes>,
#  array([[<Axes: title={'center': 'bjet_mult [sr]'}>,
#          <Axes: title={'center': 'bjet_mult [zecr]'}>,
#          <Axes: title={'center': 'bjet_mult [zmucr]'}>],
#         [<Axes: title={'center': 'bjet_mult [tecr]'}>,
#          <Axes: title={'center': 'bjet_mult [tmucr]'}>,
#          <Axes: title={'center': 'cos_theta_star [sr]'}>],
#         [<Axes: title={'center': 'cos_theta_star [zecr]'}>,
#          <Axes: title={'center': 'cos_theta_star [zmucr]'}>,
#          <Axes: title={'center': 'cos_theta_star [tecr]'}>],
#         [<Axes: title={'center': 'cos_theta_star [tmucr]'}>,
#          <Axes: title={'center': 'jet_mult [sr]'}>,
#          <Axes: title={'center': 'jet_mult [zecr]'}>],
#         [<Axes: title={'center': 'jet_mult [zmucr]'}>,
#          <Axes: title={'center': 'jet_mult [tecr]'}>,
#          <Axes: title={'center': 'jet_mult [tmucr]'}>],
#         [<Axes: title={'center': 'jet_pt [sr]'}>,
#          <Axes: title={'center': 'jet_pt [zecr]'}>,
#          <Axes: title={'center': 'jet_pt [zmucr]'}>],
#         [<Axes: title={'center': 'jet_pt [tecr]'}>,
#          <Axes: title={'center': 'jet_pt [tmucr]'}>,
#          <Axes: title={'center': 'lead_jet_pt [sr]'}>],
#         [<Axes: title={'center': 'lead_jet_pt [zecr]'}>,
#          <Axes: title={'center': 'lead_jet_pt [zmucr]'}>,
#          <Axes: title={'center': 'lead_jet_pt [tecr]'}>],
#         [<Axes: title={'center': 'lead_jet_pt [tmucr]'}>,
#          <Axes: title={'center': 'met [sr]'}>,
#          <Axes: title={'center': 'met [zecr]'}>],
#         [<Axes: title={'center': 'met [zmucr]'}>,
#          <Axes: title={'center': 'met [tecr]'}>,
#          <Axes: title={'center': 'met [tmucr]'}>],
#         [<Axes: title={'center': 'met_pf_calo_delta [sr]'}>,
#          <Axes: title={'center': 'met_pf_calo_delta [zecr]'}>,
#          <Axes: title={'center': 'met_pf_calo_delta [zmucr]'}>],
#         [<Axes: title={'center': 'met_pf_calo_delta [tecr]'}>,
#          <Axes: title={'center': 'met_pf_calo_delta [tmucr]'}>,
#          <Axes: title={'center': 'min_dphi_jets_met [sr]'}>],
#         [<Axes: title={'center': 'min_dphi_jets_met [zecr]'}>,
#          <Axes: title={'center': 'min_dphi_jets_met [zmucr]'}>,
#          <Axes: title={'center': 'min_dphi_jets_met [tecr]'}>],
#         [<Axes: title={'center': 'min_dphi_jets_met [tmucr]'}>,
#          <Axes: title={'center': 'nlep [sr]'}>,
#          <Axes: title={'center': 'nlep [zecr]'}>],
#         [<Axes: title={'center': 'nlep [zmucr]'}>,
#          <Axes: title={'center': 'nlep [tecr]'}>,
#          <Axes: title={'center': 'nlep [tmucr]'}>],
#         [<Axes: title={'center': 'recoil [sr]'}>,
#          <Axes: title={'center': 'recoil [zecr]'}>,
#          <Axes: title={'center': 'recoil [zmucr]'}>],
#         [<Axes: title={'center': 'recoil [tecr]'}>,
#          <Axes: title={'center': 'recoil [tmucr]'}>,
#          <Axes: title={'center': 'recoil_all [sr]'}>],
#         [<Axes: title={'center': 'recoil_all [zecr]'}>,
#          <Axes: title={'center': 'recoil_all [zmucr]'}>,
#          <Axes: title={'center': 'recoil_all [tecr]'}>],
#         [<Axes: title={'center': 'recoil_all [tmucr]'}>, <Axes: >,
#          <Axes: >]], dtype=object))
